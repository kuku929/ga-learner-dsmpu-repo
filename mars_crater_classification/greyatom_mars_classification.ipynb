# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV, train_test_split

# %%
data = pd.read_csv(r"C:\Users\Krutarth\Desktop\Datasets\greyatom_marsclassification\train.csv")
data.drop(columns=['Id','Unnamed: 0'],inplace=True)

# %%
data.head()
# Out:
#        attr0      attr1      attr2      attr3      attr4      attr5     attr6  \
# 0  -4.374765  13.819856  14.656331  -9.728919 -19.334897   0.344455  11.10572
# 1 -13.796261  -4.647589  21.676617  -0.122074  11.228644  -8.806895  -9.16119
# 2  -2.115400  -3.332400  -6.640000 -13.825000   4.123200  27.365000   6.70020
# 3 -25.531000  66.699000 -13.025000 -31.198000  12.016000  19.365000   5.04510
# 4  18.993000  -5.620000  -9.964900   3.307200   0.999760 -10.920000 -11.39200
#
#        attr7      attr8      attr9  ...    attr1080   attr1081   attr1082  \
# 0  21.977302  14.822923 -24.729940  ...   89.083581  86.194838  93.162055
# 1  18.025709   4.948527 -11.680861  ...  100.750899  83.373142  76.902208
# 2   3.783000   8.909500   1.453900  ...   52.917000  34.799000  42.562000
# 3  20.418000  24.372000  18.163000  ...   49.488000  71.633000  66.757000
# 4   3.918500  -1.168300   1.918500  ...   84.508000  89.976000  61.169000
#
# ...

# %%
data.shape
# Out:
# (5892, 1090)

# %%
x = data.iloc[:,:-1]
y = data.iloc[:,-1]

# %%
X_col = x.columns

# %%
scaler = StandardScaler()
X = pd.DataFrame(scaler.fit_transform(x))
X.columns = X_col

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, test_size=0.2)

# %%
parameter_grid = {"max_depth": [5,3],
              "bootstrap": [True, False],
               "n_estimators" : [200]}

# %%
classifier = RandomForestClassifier(random_state=0)

# %%
grid_search = GridSearchCV(estimator=classifier, param_grid = parameter_grid,n_jobs=20)

# %%
test = pd.read_csv(r"C:\Users\Krutarth\Desktop\Datasets\greyatom_marsclassification\test.csv")
Id = pd.DataFrame(test['Id'])
test.drop(columns=['Id','Unnamed: 0' ],inplace=True)

# %%
test = pd.DataFrame(scaler.transform(test))
test
# Out:
#           0         1         2         3         4         5         6     \
# 0    -0.216721 -0.257484 -0.280124  0.276399 -0.223298 -0.344359  0.678393
# 1     2.226202 -0.307108 -0.654488  0.009205 -0.204804 -0.249528  1.143582
# 2    -2.172011 -2.759417 -2.546321 -1.408588  1.870280  4.114325  0.952716
# 3    -0.021980 -0.155103  0.039989 -0.092344 -0.672255 -0.162081  0.195295
# 4     0.385892  0.951058  0.222002 -0.753088 -0.889077  0.532835  0.125976
# ...        ...       ...       ...       ...       ...       ...       ...
# 1468  0.478717  0.360296  0.004727  0.725098  0.038907 -0.345345  0.103231
# 1469  0.342487  1.890168  0.491014  0.062102 -0.363990  0.615739  0.419995
# 1470 -0.012862  1.078553 -0.020168 -0.667946  0.154063  0.671583 -0.113328
# 1471 -0.107766 -0.829893  0.248394  0.662291 -0.247421  0.321508  0.664183
# 1472  0.950773  0.200996 -0.942121 -0.698412  1.564527  2.079584  0.454532
#
# ...

# %%
X
# Out:
#          attr0     attr1     attr2     attr3     attr4     attr5     attr6  \
# 0    -0.210530  0.824349  0.865479 -0.453856 -1.080809 -0.106687  0.453231
# 1    -0.706308 -0.152624  1.221722  0.038882  0.507308 -0.588194 -0.632665
# 2    -0.091637 -0.083047 -0.215201 -0.663945  0.138101  1.315023  0.217185
# 3    -1.323814  3.621784 -0.539207 -1.555011  0.548220  0.894096  0.128505
# 4     1.019129 -0.204067 -0.383923  0.214770 -0.024197 -0.699376 -0.752192
# ...        ...       ...       ...       ...       ...       ...       ...
# 5887  0.201791 -0.246732 -0.990348 -0.886704 -0.801413 -0.082270  0.858026
# 5888  0.220564 -0.242159 -1.031878 -0.058491 -1.059810 -0.245087  0.842151
# 5889 -0.085128  0.346420  0.479488  0.700548  0.285477 -0.357822 -0.170079
# 5890  0.061027 -0.085332  0.384411  0.542636 -0.367785 -0.647932 -0.050550
# 5891  1.515618  0.528960 -0.982768 -1.251424 -0.647822  1.015638  0.359637
#
# ...

# %%
grid_search.fit(X,y)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(random_state=0), n_jobs=20,
#              param_grid={'bootstrap': [True, False], 'max_depth': [5, 3],
#                          'n_estimators': [200]})

# %%
predictions = grid_search.predict(test)

# %%
Id['attr1089'] = predictions

# %%
Id.attr1089.value_counts()
# Out:
# 1    792
# 0    681
# Name: attr1089, dtype: int64

# %%
cd C:\Users\Krutarth\Desktop\Datasets\greyatom_marsclassification
# Out:
# C:\Users\Krutarth\Desktop\Datasets\greyatom_marsclassification

# %%
Id.to_csv('submission.csv',index=False)
